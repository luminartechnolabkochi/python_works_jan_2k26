# %% [markdown]
# # Arithmetic operator
#
#  ## + (addition)
#  ## - (subt)
#  ## * (multiplication)
#  ## / (division)
#  ## // (floor)
#  ## % (remainder,divisor,last_digit)
#  ## **(exponent)

# %% [markdown]
# ### relational Operator (<,>,<=,>=,==,!=)

# %% [markdown]
# ### Logical operator (and , or , not)

# %%
print(True and True)
# Out:
# True

# %%
print(True and False)
# Out:
# False

# %%
print(False and False)
# Out:
# False

# %%
print(True or False)
